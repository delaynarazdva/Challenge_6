# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import pathlib as path

# %%
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\bekhr\\Desktop\\HW3\\Resources'

# %% [markdown]
# ---

# %%
# Whale

# %%
path_whale = "whale_returns.csv"

# %%
whale_returns = pd.read_csv(path_whale, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
whale_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# ...

# %%
whale_returns.isnull()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                       True                True
# 2015-03-03                      False               False
# 2015-03-04                      False               False
# 2015-03-05                      False               False
# 2015-03-06                      False               False
# ...                               ...                 ...
# 2019-04-25                      False               False
# 2019-04-26                      False               False
# 2019-04-29                      False               False
# 2019-04-30                      False               False
# 2019-05-01                      False               False
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                         True                    True
# 2015-03-03                        False                   False
# ...

# %%
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
whale_returns.dropna(inplace=True)

# %%
whale_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %%
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ---

# %%
# Algo

# %%
path_algo = "algo_returns.csv"

# %%
algo_returns = pd.read_csv(path_algo, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
algo_returns
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %%
algo_returns.isnull()
# Out:
#             Algo 1  Algo 2
# Date
# 2014-05-28   False    True
# 2014-05-29   False    True
# 2014-05-30   False    True
# 2014-06-02   False    True
# 2014-06-03   False    True
# ...            ...     ...
# 2019-04-25   False   False
# 2019-04-26   False   False
# 2019-04-29   False   False
# 2019-04-30   False   False
# 2019-05-01   False   False
#
# [1241 rows x 2 columns]

# %%
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
algo_returns.dropna(inplace=True)

# %%
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ---

# %%
# Sp500

# %%
path_sp500 = "sp500_history.csv"

# %%
sp_500 = pd.read_csv(path_sp500, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
sp_500.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
### rempve the $ signs
### convert into float

# %%
sp_500['Close'] = sp_500['Close'].str.replace("$", "")
# Out:
# C:\Users\bekhr\AppData\Local\Temp\ipykernel_26704\1436441389.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp_500['Close'] = sp_500['Close'].str.replace("$", "")

# %%
sp_500.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp_500.head()
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
sp_500['Close']=sp_500['Close'].astype("float")

# %%
sp_500.dtypes
# Out:
# Close    float64
# dtype: object

# %%
sp_500= sp_500.pct_change()
sp_500.dropna(inplace=True)
sp_500.head()
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
sp_500.head()
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
sp_500 = sp_500.rename(columns={
    "Close": "SP500"
})

# %%
sp_500.head()
# Out:
#                SP500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %% [markdown]
# ---

# %%
# Combined

# %%
combined_df = pd.concat([whale_returns, algo_returns, sp_500], axis=1, join="inner")

# %%
combined_df.dropna(inplace=True)

# %%
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     SP500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %% [markdown]
# ---

# %%
# Analysis

# %%
list(combined_df)
# Out:
# ['SOROS FUND MANAGEMENT LLC',
#  'PAULSON & CO.INC. ',
#  'TIGER GLOBAL MANAGEMENT LLC',
#  'BERKSHIRE HATHAWAY INC',
#  'Algo 1',
#  'Algo 2',
#  'SP500']

# %%
combined_df.plot(figsize=(20,10), use_index=True, y="SOROS FUND MANAGEMENT LLC")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
combined_df.plot(figsize=(20,10), use_index=True, y="Algo 2")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
combined_df.plot(figsize=(20,10),use_index=True, y="TIGER GLOBAL MANAGEMENT LLC")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
combined_df.plot(figsize=(20,10),use_index=True, y="PAULSON & CO.INC. ")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
combined_df.plot(figsize=(20,10),use_index=True, y="BERKSHIRE HATHAWAY INC")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
combined_df.plot(figsize=(20,10),use_index=True, y="SP500")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
combined_df.mean()
# Out:
# SOROS FUND MANAGEMENT LLC      0.000171
# PAULSON & CO.INC.             -0.000217
# TIGER GLOBAL MANAGEMENT LLC   -0.000089
# BERKSHIRE HATHAWAY INC         0.000494
# Algo 1                         0.000658
# Algo 2                         0.000254
# SP500                         -0.000281
# dtype: float64

# %%
combined_df.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# STD
combined_df.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# SP500                          0.008587
# dtype: float64

# %%
### Tiger Global & Berkshire Hathaway have the highest std

# %%
combined_df.std()*np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# SP500                          0.136313
# dtype: float64

# %%
combined_df.rolling(window=21).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
combined_df.corr()
sns.heatmap(combined_df.corr(),vmin=1,vmax=-1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---

# %%
### Calculate and Plot Beta

# %%
covariance = combined_df['Algo 1'].cov(combined_df['SP500'])
covariance
# Out:
# -2.2230425517155125e-06

# %%
variance = combined_df["SP500"].var()
variance
# Out:
# 7.373467552840441e-05

# %%
sp500_beta = covariance / variance
sp500_beta
# Out:
# -0.03014921454233757

# %% [markdown]
# ---

# %%
### Rolling Statistics Challenge

# %%
ewm = combined_df.ewm(span=21, adjust=False).std()

# %%
ewm
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                   0.002472            0.005814
# 2015-03-05                   0.003128            0.005977
# 2015-03-06                   0.004173            0.004862
# 2015-03-09                   0.003664            0.005217
# ...                               ...                 ...
# 2019-04-15                   0.005817            0.005879
# 2019-04-16                   0.005551            0.005606
# 2019-04-17                   0.005487            0.005727
# 2019-04-18                   0.005232            0.005475
# 2019-04-22                   0.005136            0.005650
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                     0.001441                0.007624  0.004700
# ...

# %% [markdown]
# ---

# %%
### Sharpe Ratios

# %%
sharpe_r = combined_df.mean() / combined_df.std()

# %%
sharpe_r
# Out:
# SOROS FUND MANAGEMENT LLC      0.021600
# PAULSON & CO.INC.             -0.030957
# TIGER GLOBAL MANAGEMENT LLC   -0.008201
# BERKSHIRE HATHAWAY INC         0.038221
# Algo 1                         0.086276
# Algo 2                         0.030510
# SP500                         -0.032668
# dtype: float64

# %%
annual_sharpe_r = sharpe_r*np.sqrt(252)

# %%
annual_sharpe_r
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# SP500                         -0.518582
# dtype: float64

# %%
annual_sharpe_r.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---

# %%
###  Custom Portfolio

# %%
pwd
# Out:
# 'C:\\Users\\bekhr\\Desktop\\HW3\\Resources'

# %%
path_costco = "cost_historical.csv"

# %%
costco = pd.read_csv(path_costco, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)

# %%
costco
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62
# ...           ...     ...
# 2018-05-17   COST  199.60
# 2018-05-16   COST  198.71
# 2018-05-15   COST  195.48
# 2018-05-14   COST  195.88
# 2018-05-11   COST  195.76
#
# [250 rows x 2 columns]

# %%
costco.rename(columns= {"NOCP":"Costco"}, inplace=True)

# %%
costco.drop(columns=["Symbol"], inplace=True)

# %%
costco
# Out:
#             Costco
# Trade DATE
# 2019-05-09  243.47
# 2019-05-08  241.34
# 2019-05-07  240.18
# 2019-05-06  244.23
# 2019-05-03  244.62
# ...            ...
# 2018-05-17  199.60
# 2018-05-16  198.71
# 2018-05-15  195.48
# 2018-05-14  195.88
# 2018-05-11  195.76
#
# [250 rows x 1 columns]

# %%
costco = costco.sort_index(ascending=True)

# %%
costco
# Out:
#             Costco
# Trade DATE
# 2018-05-11  195.76
# 2018-05-14  195.88
# 2018-05-15  195.48
# 2018-05-16  198.71
# 2018-05-17  199.60
# ...            ...
# 2019-05-03  244.62
# 2019-05-06  244.23
# 2019-05-07  240.18
# 2019-05-08  241.34
# 2019-05-09  243.47
#
# [250 rows x 1 columns]

# %%
path_google = "goog_historical.csv"

# %%
google = pd.read_csv(path_google)

# %%
google
# Out:
#     Symbol Trade DATE     NOCP
# 0     GOOG   5/9/2019  1162.38
# 1     GOOG   5/8/2019  1166.27
# 2     GOOG   5/7/2019  1174.10
# 3     GOOG   5/6/2019  1189.39
# 4     GOOG   5/3/2019  1185.40
# ..     ...        ...      ...
# 245   GOOG  5/17/2018  1078.59
# 246   GOOG  5/16/2018  1081.77
# 247   GOOG  5/15/2018  1079.23
# 248   GOOG  5/14/2018  1100.20
# 249   GOOG  5/11/2018  1098.26
#
# [250 rows x 3 columns]

# %%
google = pd.read_csv(path_google, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)

# %%
google
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40
# ...           ...      ...
# 2018-05-17   GOOG  1078.59
# 2018-05-16   GOOG  1081.77
# 2018-05-15   GOOG  1079.23
# 2018-05-14   GOOG  1100.20
# 2018-05-11   GOOG  1098.26
#
# [250 rows x 2 columns]

# %%
google.drop(columns=["Symbol"], inplace=True)

# %%
google.rename(columns={"NOCP":"Google"}, inplace=True)
google = google.sort_index(ascending=True)

# %%
google
# Out:
#              Google
# Trade DATE
# 2018-05-11  1098.26
# 2018-05-14  1100.20
# 2018-05-15  1079.23
# 2018-05-16  1081.77
# 2018-05-17  1078.59
# ...             ...
# 2019-05-03  1185.40
# 2019-05-06  1189.39
# 2019-05-07  1174.10
# 2019-05-08  1166.27
# 2019-05-09  1162.38
#
# [250 rows x 1 columns]

# %%
apple_path = "aapl_historical.csv"

# %%
apple = pd.read_csv(apple_path, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
apple.drop(columns=["Symbol"], inplace=True)
apple.rename(columns= {"NOCP":"Apple"}, inplace=True)
apple = apple.sort_index(ascending=True)

# %%
apple
# Out:
#              Apple
# Trade DATE
# 2018-05-11  188.59
# 2018-05-14  188.15
# 2018-05-15  186.44
# 2018-05-16  188.18
# 2018-05-17  186.99
# ...            ...
# 2019-05-03  211.75
# 2019-05-06  208.48
# 2019-05-07  202.86
# 2019-05-08  202.90
# 2019-05-09  200.72
#
# [250 rows x 1 columns]

# %%
combined_stocks = pd.concat([costco, apple, google], axis=1, join="inner")
combined_stocks
# Out:
#             Costco   Apple   Google
# Trade DATE
# 2018-05-11  195.76  188.59  1098.26
# 2018-05-14  195.88  188.15  1100.20
# 2018-05-15  195.48  186.44  1079.23
# 2018-05-16  198.71  188.18  1081.77
# 2018-05-17  199.60  186.99  1078.59
# ...            ...     ...      ...
# 2019-05-03  244.62  211.75  1185.40
# 2019-05-06  244.23  208.48  1189.39
# 2019-05-07  240.18  202.86  1174.10
# 2019-05-08  241.34  202.90  1166.27
# 2019-05-09  243.47  200.72  1162.38
#
# [250 rows x 3 columns]

# %%
combined_stocks.dropna(inplace=True)

# %%
daily_returns_combined_stocks = combined_stocks.pct_change()

# %%
daily_returns_combined_stocks
# Out:
#               Costco     Apple    Google
# Trade DATE
# 2018-05-11       NaN       NaN       NaN
# 2018-05-14  0.000613 -0.002333  0.001766
# 2018-05-15 -0.002042 -0.009088 -0.019060
# 2018-05-16  0.016523  0.009333  0.002354
# 2018-05-17  0.004479 -0.006324 -0.002940
# ...              ...       ...       ...
# 2019-05-03  0.007953  0.012431  0.019602
# 2019-05-06 -0.001594 -0.015443  0.003366
# 2019-05-07 -0.016583 -0.026957 -0.012855
# 2019-05-08  0.004830  0.000197 -0.006669
# 2019-05-09  0.008826 -0.010744 -0.003335
#
# [250 rows x 3 columns]

# %%
daily_returns_combined_stocks.dropna()
# Out:
#               Costco     Apple    Google
# Trade DATE
# 2018-05-14  0.000613 -0.002333  0.001766
# 2018-05-15 -0.002042 -0.009088 -0.019060
# 2018-05-16  0.016523  0.009333  0.002354
# 2018-05-17  0.004479 -0.006324 -0.002940
# 2018-05-18 -0.003206 -0.003637 -0.011339
# ...              ...       ...       ...
# 2019-05-03  0.007953  0.012431  0.019602
# 2019-05-06 -0.001594 -0.015443  0.003366
# 2019-05-07 -0.016583 -0.026957 -0.012855
# 2019-05-08  0.004830  0.000197 -0.006669
# 2019-05-09  0.008826 -0.010744 -0.003335
#
# [249 rows x 3 columns]

# %%
weighted_returns = [1/3, 1/3, 1/3]

# %%
combined_weighted_returns = daily_returns_combined_stocks.dot(weighted_returns)

# %%
combined_weighted_returns.head()
# Out:
# Trade DATE
# 2018-05-11         NaN
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# dtype: float64

# %%
combined_df.std()*np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# SP500                          0.136313
# dtype: float64

# %%
combined_df.rolling(window=21)
# Out:
# Rolling [window=21,center=False,axis=0,method=single]

# %%
combined_df.rolling(window=21).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
combined_df.corr().plot()
# Out:
# <AxesSubplot:>
